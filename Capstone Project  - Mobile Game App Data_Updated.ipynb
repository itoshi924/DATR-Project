# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
from itertools import product

# %% [markdown]
# # 0. Introduction

# %% [markdown]
# [ADDITIONAL] Mobile gaming is one of the most globally. Japan, in particular, attracts many mobile game operators. Given the high degree of competition within the industry, I believe this report can serve to provide guidelines to indicate the type of mobile games that can be monetized effectively. In this project, I classify the genres of mobile game apps by the method of k-means clustering depending on SimilarWeb's grossing rank and Google Play's user rate. The motivation comes from the great degree of business uncertainty that is sprevelent in the mobile gaming industry in Japan, which is commonly regarded as a red ocean. The aim of the project is to provide information through its results which can be useful in strategy
# planning and decision making for the mobile gaming operators, primarily targerting the Japan market. Working for a stock analyst covering gaming companies publicly listed in Japan, I was also intersted in conducting data science analytics on this market, which is the primary motivation behind my enrolment in General Assembly's Data Science Immersive Remote course.

# %% [markdown]
# # 1. Import Data:

# %% [markdown]
# [ADDITIONAL] The data that we used for our analysis consist of the following:
#  The historical average of the grossing ranking for 289 games that have ranked top 50 on SimilarWeb for 450 days. Here, the lower the rank values are, the higher ranks or the more popular (1 >>> 50).
#  The latest user rating, the number of users who provided such rating, the cumulative download cases and the genre for the above games on Google Play. In the following section, we make a k-means cluster analysis in order to classify genres of the most highly-ranked and highly-rated mobile games.
# For the purpose of my day-to-day jobs, I solely focused upon SimilarWeb's grossing ranking. However, since it lacks deeper insights into what makes a particular mobile game app popular, I decided to gather more qualitative data sets from Google Play.

# %% [markdown]
# [ADDITIONAL] In this section, I imported a csv file which compiles the aforementioned KPI data sets for 289 games that have ranked top 50 on SimilarWeb for 450 days. For this purpose, I have used Selenium to scrape the latest user rating, the number of users who provided such rating, the cumulative download cases and the genre type for the above games from Google Play.

# %%
games = pd.read_csv("Mobile_Game_Data.csv")

# %%
games.shape
# Out:
# (289, 13)

# %%
games.head()
# Out:
#                              title      publisher capital    rank         dl  \
# 0          Uma Musume Pretty Derby  Cygames, Inc.  Public   4.973    1000000
# 1               Fate / Grand Order   Aniplex Inc.  Public   8.272    1000000
# 2                   Monster Strike    XFLAG, Inc.  Public   4.768   10000000
# 3                       Pokémon GO  Niantic, Inc.  Public  10.194  100000000
# 4  Professional Baseball Spirits A         KONAMI  Public   5.984    1000000
#
#    rating    review          tag1                 tag2                tag3  \
# 0     4.0     97100    Simulation             Breeding            Stylized
# 1     3.8    169000  Role Playing       Turn-based RPG       Single player
# 2     4.0    785000  Role Playing  Puzzle Role-playing  Physics-puzzle RPG
# 3     3.7  15400000        Action     Action-adventure         Multiplayer
# 4     4.2     91800        Sports             Baseball         Multiplayer
#
#                       tag4           tag5       tag6
# 0                    Anime              -          -
# 1                 Stylized          Anime          -
# 2            Single player       Stylized      Anime
# 3  Competitive multiplayer       Stylized      Anime
# 4  Competitive multiplayer  Single player  Realistic

# %% [markdown]
# # 2. Clean Up Data:

# %% [markdown]
# [ADDITIONAL] For the second step, I did not have to do much of data cleaning, except for converting "-" values to null data.

# %%
# total nulls
games.isnull().sum()
# Out:
# title        0
# publisher    0
# capital      0
# rank         0
# dl           0
# rating       0
# review       0
# tag1         0
# tag2         0
# tag3         0
# tag4         0
# tag5         0
# tag6         0
# dtype: int64

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      289 non-null    object
#  1   publisher  289 non-null    object
#  2   capital    289 non-null    object
#  3   rank       289 non-null    float64
#  4   dl         289 non-null    int64
#  5   rating     289 non-null    float64
#  6   review     289 non-null    int64
#  7   tag1       289 non-null    object
#  8   tag2       289 non-null    object
#  9   tag3       289 non-null    object
#  10  tag4       289 non-null    object
#  11  tag5       289 non-null    object
#  12  tag6       289 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 29.5+ KB

# %%
# Convert the download column to integer
games['dl'] = games.dl.replace('-',).astype('int')

# %%
# Convert the rating column to float
games['rating'] = games.rating.replace('-',).astype('float')

# %%
# Convert the review column to integer
games['review'] = games.review.replace('-',).astype('int')

# %%
# Convert the null genre to 'Others'
games['review'] = games.review.replace('-',).astype('int')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      289 non-null    object
#  1   publisher  289 non-null    object
#  2   capital    289 non-null    object
#  3   rank       289 non-null    float64
#  4   dl         289 non-null    int64
#  5   rating     289 non-null    float64
#  6   review     289 non-null    int64
#  7   tag1       289 non-null    object
#  8   tag2       289 non-null    object
#  9   tag3       289 non-null    object
#  10  tag4       289 non-null    object
#  11  tag5       289 non-null    object
#  12  tag6       289 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 29.5+ KB

# %%
# summary statistics
games.describe()
# Out:
#              rank            dl      rating        review
# count  289.000000  2.890000e+02  289.000000  2.890000e+02
# mean    34.291529  1.280131e+07    3.885467  1.180028e+06
# std      9.600726  4.762886e+07    0.500413  5.155533e+06
# min      3.167000  1.000000e+04    0.000000  0.000000e+00
# 25%     30.135000  1.000000e+05    3.700000  1.040000e+04
# 50%     36.000000  1.000000e+06    4.000000  3.230000e+04
# 75%     41.000000  1.000000e+06    4.200000  1.470000e+05
# max     50.000000  5.000000e+08    5.000000  5.980000e+07

# %%
games.nunique()
# Out:
# title        276
# publisher    149
# capital        2
# rank         232
# dl            10
# rating        28
# review       239
# tag1          15
# tag2          45
# tag3          18
# tag4          11
# tag5          11
# tag6          10
# dtype: int64

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      289 non-null    object
#  1   publisher  289 non-null    object
#  2   capital    289 non-null    object
#  3   rank       289 non-null    float64
#  4   dl         289 non-null    int64
#  5   rating     289 non-null    float64
#  6   review     289 non-null    int64
#  7   tag1       289 non-null    object
#  8   tag2       289 non-null    object
#  9   tag3       289 non-null    object
#  10  tag4       289 non-null    object
#  11  tag5       289 non-null    object
#  12  tag6       289 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 29.5+ KB

# %% [markdown]
# # 3. Exploratory Data Analysis:

# %% [markdown]
# ****Game production per publiisher****

# %% [markdown]
# [ADDITIONAL] In the next step, I conducted EDA to understand the distribution of those mobile game apps, understand the overall trends and patterns in behind my data set and thus observe the type of genres that are most popular as measured by the SimilarWeb grossing ranking and Google Play rating.
# Through the EDA below, I found that "Music", "Puzzle", "Strategy" and "Simulation" games tend to rank and rate higher than those which fall under other categories.

# %% [markdown]
# [ADDITIONAL] Ultimately, the EDA was conducted below to extract the correlation between attributes belonging to the mobile game apps. Unsurprisingly, the ranking data and rating data are negatively correlated while download cases and the number of users who rated apps on Google Play are positively correlated. However, I had to conduct K-means clustering to do deep dive analysis into what makes a particular mobile game app popular on SimilarWeb (by means of grossing ranks) and Google Play (by means of rating).

# %%
# The number of games published by each publisher
games.publisher.value_counts()
# Out:
# BANDAI NAMCO Entertainment Inc.    21
# SQUARE ENIX                        20
# KONAMI                             10
# SEGA CORPORATION                    6
# KLab Inc.                           6
#                                    ..
# Cookies Inc.                        1
# g1dash, Inc.                        1
# Npixel Co., Ltd.                    1
# 株式会社miHoYo                          1
# Nuverse (Hong Kong) Limited         1
# Name: publisher, Length: 149, dtype: int64

# %% [markdown]
# **Genre**

# %%
# Visualize the number of games for each genre using a countplot
games.tag1.value_counts().plot(kind='barh', title='No. of games published by each genre').invert_yaxis();
plt.xlabel(games.tag1.any());
plt.ylabel('Genre');

# %% [markdown]
# **Ratings**

# %%
# 10 Highest rated games
games.nlargest(10,'rating')
# Out:
#                                    title                          publisher  \
# 136  Hypnosismic -Alternative Rap Battle         Idea Factory Plus Co., Ltd
# 7                       Puzzle & Dragons  GungHo Online Entertainment, Inc.
# 130                     Puzzle & Dragons  GungHo Online Entertainment, Inc.
# 111                Top War: Battle Game                       Topwar Studio
# 109                     Tenchi no Gotoku                     Six Waves Inc.
# 288                    Kirameki Paradise               Famous Heart Limited
# 23                              Idolish7           BANDAI NAMCO Online Inc.
# 31                             Arknights                       Yostar, Inc.
# 118     The Symphony of Dragon and Girls              BluStar Games Limited
# 183                                Evony                     TOP GAMES INC.
#
#      capital    rank         dl  rating  review          tag1            tag2  \
# 136  Private  30.714     500000     5.0   27000         Music     Performance
# 7     Public   7.597   10000000     4.9  142000        Puzzle          Jigsaw
# 130   Public   7.597   10000000     4.9  142000        Puzzle          Jigsaw
# 111  Private  35.848   50000000     4.8  704000      Strategy  Build & battle
# 109   Public  45.250     100000     4.7    5670      Strategy  Build & battle
# 288  Private  45.000      50000     4.7     855    Simulation       Lifestyle
# 23    Public  31.250     500000     4.6   48200         Music     Performance
# 31   Private  25.721    1000000     4.6   27000      Strategy   Tower defense
# 118  Private  41.545     100000     4.6   24900  Role Playing          Casual
# 183   Public  41.000  100000000     4.6  801000      Strategy  Build & battle
#
#               tag3                     tag4                     tag5  \
# 136  Single player                 Stylized                    Anime
# 7           Casual            Single player                Realistic
# 130         Casual            Single player                Realistic
# 111    Multiplayer  Competitive multiplayer                 Stylized
# 109  Single player                 Stylized       Stylized-realistic
# 288       Dress-up            Single player                 Stylized
# 23        Stylized                    Anime                        -
# 31   Single player                 Stylized                    Anime
# 118       Stylized                    Anime                        -
# 183         Casual              Multiplayer  Competitive multiplayer
#
#                    tag6
# 136                   -
# 7               Offline
# 130             Offline
# 111                   -
# 109                   -
# 288  Stylized-realistic
# 23                    -
# 31                    -
# 118                   -
# 183       Single player

# %%
# Visualize the distribution or rating
plt.style.use('bmh')
fig, ax = plt.subplots(figsize=(8,6))
sns.histplot(x='rating',data=games,bins=np.arange(1.5,5,0.25),ax=ax,alpha=0.3)
plt.axvline(games.rating.mean(),color='r',ls='--',label='mean')
plt.axvline(games.rating.median(),color='k',ls='-',label='median')
plt.title('Distribution of games ratings')
plt.legend()
plt.show()

# %%
# Average of average rating by category
games.groupby("tag1").mean()['rating'].sort_values(ascending = True).plot(kind = 'barh', title = 'average rating by genre')
# Out:
# <AxesSubplot:title={'center':'average rating by genre'}, ylabel='tag1'>

# %%
# 10 Lowest rated games
games.nsmallest(10,'rating')
# Out:
#                                         title  \
# 169                          Ragnarok Masters
# 279  Mobile Suit Gundam: Iron-Blooded Orphans
# 132                       Laguna Roque Origin
# 204            Ragnarok Origin: MMORPG Online
# 234                          Yggdra Resonance
# 244                  Shin Nobunaga's Ambition
# 113                           Shin Sangokushi
# 215                     Lineage 2: Revolution
# 236                            Echoes of Mana
# 277                 Date A Live Spirit Crisis
#
#                                publisher  capital    rank      dl  rating  \
# 169    GungHo Online Entertainment, Inc.   Public  43.400  100000     0.0
# 279      Bandai Namco Entertainment Inc.   Public  41.667   50000     2.1
# 132          GungHo Online Entertainment   Public  37.636  100000     2.2
# 204    GungHo Online Entertainment, Inc.   Public  44.706  100000     2.2
# 234                           Nuverse KK  Private  38.500  100000     2.3
# 244                               HKBBGL  Private  31.185  100000     2.4
# 113            HK HERO ENTERTAINMENT CO.  Private  41.162  100000     2.8
# 215                Netmarble Corporation   Public  44.750  500000     2.9
# 236                          SQUARE ENIX   Public  34.400  100000     2.9
# 277  PANDA INTERACTIVE HONG KONG LIMITED  Private  35.500   50000     2.9
#
#      review          tag1            tag2           tag3  \
# 169       0  Role Playing          MMORPG    Multiplayer
# 279    1340  Role Playing               -              -
# 132    2020  Role Playing          MMORPG    Multiplayer
# 204    2020  Role Playing          MMORPG    Multiplayer
# 234    4280  Role Playing  Turn-based RPG         Casual
# 244    6790      Strategy         Wargame  Single player
# 113    6820      Strategy  Build & battle         Casual
# 215   25800  Role Playing          MMORPG    Multiplayer
# 236    5980        Action   Single player       Stylized
# 277    1100        Action               -              -
#
#                         tag4           tag5                tag6
# 169  Cooperative multiplayer  Single player            Stylized
# 279                        -              -                   -
# 132  Cooperative multiplayer  Single player            Stylized
# 204  Cooperative multiplayer  Single player            Stylized
# 234            Single player       Stylized               Anime
# 244                 Stylized              -                   -
# 113                 Stylized              -                   -
# 215            Single player       Stylized  Stylized-realistic
# 236                    Anime              -                   -
# 277                        -              -                   -

# %%
# Which genre produced majority of the top 100 rated games
highest_rated_100 = games.loc[games.rating.nlargest(100).index,['tag1']].value_counts().reset_index()
highest_rated_100['tag1'] = highest_rated_100.tag1

# Visualize
sns.set_palette('Spectral')
fig, ax = plt.subplots(figsize=(8,6))
plt.pie(highest_rated_100[0],labels=highest_rated_100.tag1,shadow=True,autopct='%1.0f%%')
ax.set(title='Percentage of 100 highest rated games per genre')
plt.show()

# %%
# Get the top rated games
highest_rated_games = games.loc[games.rating.nlargest(100).index,['title','publisher','capital','rating','review','tag1']]
highest_rated_games.head(25)
# Out:
#                                                  title  \
# 136                Hypnosismic -Alternative Rap Battle
# 7                                     Puzzle & Dragons
# 130                                   Puzzle & Dragons
# 111                              Top War: Battle Game
# 109                                   Tenchi no Gotoku
# 288                                  Kirameki Paradise
# 23                                            Idolish7
# 31                                           Arknights
# 118                   The Symphony of Dragon and Girls
# 183                                              Evony
# 10                            Ensemble Stars! !! Music
# 32                                                 A3!
# 114                                  State of Survival
# 179                                          Lineage W
# 210                              Touken Ranbu - ONLINE
# 250                            BTS Island: In the SEOM
# 252                                          Lineage W
# 256                                       Survivor!.io
# 260                         Touken Ranbu ONLINE Pocket
# 272                                        Echocalypse
# 285                                          Lineage W
# 8                                       Genshin Impact
# 16   Project Sekai: Colorful Stage! feat. Hatsune Miku
# 43                                       Alchemy Stars
# 50                     eBaseball Powerful Pro Baseball
#
#                              publisher  capital  rating   review          tag1
# 136         Idea Factory Plus Co., Ltd  Private     5.0    27000         Music
# 7    GungHo Online Entertainment, Inc.   Public     4.9   142000        Puzzle
# 130  GungHo Online Entertainment, Inc.   Public     4.9   142000        Puzzle
# 111                      Topwar Studio  Private     4.8   704000      Strategy
# 109                     Six Waves Inc.   Public     4.7     5670      Strategy
# 288               Famous Heart Limited  Private     4.7      855    Simulation
# 23            BANDAI NAMCO Online Inc.   Public     4.6    48200         Music
# 31                        Yostar, Inc.  Private     4.6    27000      Strategy
# 118              BluStar Games Limited  Private     4.6    24900  Role Playing
# 183                     TOP GAMES INC.   Public     4.6   801000      Strategy
# 10                  Happy Elements K.K  Private     4.5    19800         Music
# 32                            Liberent   Public     4.5    13900    Simulation
# 114        KingsGroup International AG   Public     4.5    20500      Strategy
# 179                             NCSOFT   Public     4.5   147000  Role Playing
# 210                          EXNOA LLC  Private     4.5    43900  Role Playing
# 250                   HYBE IM Co.,Ltd.   Public     4.5   445000        Puzzle
# 252                             NCSOFT   Public     4.5   147000  Role Playing
# 256                              HABBY  Private     4.5   532000  Role Playing
# 260                          EXNOA LLC  Private     4.5    43900  Role Playing
# 272       YOOZOO (SINGAPORE) PTE. LTD.   Public     4.5    34900  Role Playing
# 285                             NCSOFT   Public     4.5   147000  Role Playing
# 8                       miHoYo Limited  Private     4.4  3810000  Role Playing
# 16                    SEGA CORPORATION   Public     4.4    97300         Music
# 43            PROXIMA BETA PTE.LIMITED   Public     4.4   197000  Role Playing
# 50                              KONAMI   Public     4.4    96500        Sports

# %%
# Which genre produced majority of the lowest 100 rated games
lowest_rated_100 = games.loc[games.rating.nsmallest(100).index,['tag1']].value_counts().reset_index()
lowest_rated_100['tag1'] = lowest_rated_100.tag1

# Visualize
sns.set_palette('Spectral')
fig, ax = plt.subplots(figsize=(8,6))
plt.pie(lowest_rated_100[0],labels=lowest_rated_100.tag1,shadow=True,autopct='%1.0f%%')
ax.set(title='Percentage of 100 lowest rated games per genre')
plt.show()

# %%
# Get the least rated games
lowest_rated_games = games.loc[games.rating.nsmallest(100).index,['title','publisher','capital','rating','review','tag1']]
lowest_rated_games
# Out:
#                                         title  \
# 169                          Ragnarok Masters
# 279  Mobile Suit Gundam: Iron-Blooded Orphans
# 132                       Laguna Roque Origin
# 204            Ragnarok Origin: MMORPG Online
# 234                          Yggdra Resonance
# ..                                        ...
# 78                               Mahjong Soul
# 101        Dragon Quest Monsters Super Light
# 104                         OCTOPATH TRAVELER
# 129                \nSaint Seiya: Rising Cosm
# 140                             Drift Spirits
#
#                              publisher  capital  rating  review          tag1
# 169  GungHo Online Entertainment, Inc.   Public     0.0       0  Role Playing
# 279    Bandai Namco Entertainment Inc.   Public     2.1    1340  Role Playing
# 132        GungHo Online Entertainment   Public     2.2    2020  Role Playing
# 204  GungHo Online Entertainment, Inc.   Public     2.2    2020  Role Playing
# 234                         Nuverse KK  Private     2.3    4280  Role Playing
# ..                                 ...      ...     ...     ...           ...
# 78                        Yostar, Inc.  Private     3.8   75700         Board
# 101                        SQUARE ENIX   Public     3.8  137000  Role Playing
# 104                        SQUARE ENIX   Public     3.8   25900  Role Playing
# 129                           Tencent    Public     3.8   23600  Role Playing
# 140    BANDAI NAMCO Entertainment Inc.   Public     3.8   49400        Racing
#
# [100 rows x 6 columns]

# %% [markdown]
# **SimilarWeb Grossing Ranking**

# %%
# sorting by the ranking in ascending order
games_ranking = games.sort_values('rank',ascending=True).reset_index().drop('index',axis=1)
games_ranking
# Out:
#                                     title                        publisher  \
# 0               GODDESS OF VICTORY: NIKKE                   Level Infinite
# 1                          Monster Strike                      XFLAG, Inc.
# 2                 Uma Musume Pretty Derby                    Cygames, Inc.
# 3         Professional Baseball Spirits A                           KONAMI
# 4           Genshin Impact - Sumeru Debut            COGNOSPHERE PTE. LTD.
# ..                                    ...                              ...
# 284  Akashic Chronicle-Apocalypse Of Dawn                         Moonton
# 285       Forsaken World: Gods and Demons                 4399 NET LIMITED
# 286  Ikémen Sengoku: Romances Across Time                 CYBIRD Co., Ltd.
# 287              THE IDOLM@STER POP LINKS  BANDAI NAMCO Entertainment Inc.
# 288                           KOF ALLSTAR            Netmarble Corporation
#
#      capital    rank        dl  rating   review          tag1  \
# 0     Public   3.167   1000000     4.1   318000  Role Playing
# 1     Public   4.768  10000000     4.0   785000  Role Playing
# 2     Public   4.973   1000000     4.0    97100    Simulation
# 3     Public   5.984   1000000     4.2    91800        Sports
# 4    Private   7.027  50000000     4.4  3810000  Role Playing
# ..       ...     ...       ...     ...      ...           ...
# 284  Private  49.000    100000     4.1    11400  Role Playing
# 285  Private  49.333    100000     3.0     4710  Role Playing
# 286   Public  50.000   1000000     3.9    12700    Simulation
# 287   Public  50.000    100000     3.9     5420  Role Playing
# 288   Public  50.000    100000     3.3    15900        Action
#
#                     tag2                tag3                     tag4  \
# 0    Action Role-Playing              Casual            Single player
# 1    Puzzle Role-playing  Physics-puzzle RPG            Single player
# 2               Breeding            Stylized                    Anime
# 3               Baseball         Multiplayer  Competitive multiplayer
# 4    Action Role-Playing       Single player                 Stylized
# ..                   ...                 ...                      ...
# 284             Idle RPG       Single player                 Stylized
# 285               MMORPG       Single player                 Stylized
# 286                 Life              Dating            Single player
# 287                    -                   -                        -
# 288             Fighting       Single player                 Stylized
#
#                    tag5       tag6
# 0              Stylized      Anime
# 1              Stylized      Anime
# 2                     -          -
# 3         Single player  Realistic
# 4                 Anime          -
# ..                  ...        ...
# 284               Anime          -
# 285  Stylized-realistic          -
# 286            Stylized      Anime
# 287                   -          -
# 288               Anime          -
#
# [289 rows x 13 columns]

# %%
# Average of average ranking by category
games.groupby("tag1").mean()['rank'].sort_values(ascending = False).plot(kind = 'barh', title = 'average ranking by genre')
# Out:
# <AxesSubplot:title={'center':'average ranking by genre'}, ylabel='tag1'>

# %%
# Show top 50 results 
display(games_ranking[['title','publisher','rank','rating','review','tag1']].nsmallest(50,'rank'))
# Out:
#                                                 title  \
# 0                           GODDESS OF VICTORY: NIKKE
# 1                                      Monster Strike
# 2                             Uma Musume Pretty Derby
# 3                     Professional Baseball Spirits A
# 4                       Genshin Impact - Sumeru Debut
# 5                                    Puzzle & Dragons
# 6                                    Puzzle & Dragons
# 7                                  Fate / Grand Order
# 8                                      Genshin Impact
# 9                                          Pokémon GO
# 10                                MementoMori: AFKRPG
# 11                                         Knives Out
# 12                                  Dragon Quest Walk
# 13                      Puzzles & Survival × G.I. Joe
# 14                                 Puzzles & Survival
# 15                        Dragon Ball Z Dokkan Battle
# 16                           Ensemble Stars! !! Music
# 17                        Romancing SaGa Re: Universe
# 18                        Romancing SaGa Re: Universe
# 19                    Abandoned Girl: Moehime's Story
# 20        Hōchi Shōjo: Hyakka Ryōran no Moehime-tachi
# 21                                   Heaven Burns Red
# 22                         Nobunaga's Ambition: Hadou
# 23  Project Sekai: Colorful Stage! feat. Hatsune Miku
# 24                                   Tower of Fantasy
# 25                      Shido no Hama – Daisangokushi
# 26           The Eminence in Shadow: Master of Garden
# 27                              One Piece Bounty Rush
# 28                              ONE PIECE Bounty Rush
# 29                              One Piece Bounty Rush
# 30                         Romancing SaGa Re;univerSe
# 31            Forest Fantasy Legend of the World Tree
# 32                             Yu-Gi-Oh! Master Duel
# 33                          One Piece Treasure Cruise
# 34                             LINE: Disney Tsum Tsum
# 35                         Fullmetal Alchemist Mobile
# 36                                  Dragon Quest Tact
# 37                      Mafia City: War of Underworld
# 38                                Dragon Ball Legends
# 39                        Sky: Children of the Light
# 40  Tokyo Revengers Pazuribe! Road to National Dom...
# 41                                        Echocalypse
# 42                                    eFootball™ 2023
# 43                          Disney Twisted Wonderland
# 44                                   Granblue fantasy
# 45                                #COMPASS Live Arena
# 46                    eBaseball Powerful Pro Baseball
# 47                                      LINE PokoPoko
# 48                                          Arknights
# 49                 Dragon Quest Monsters Super Light
#
#                             publisher    rank  rating    review          tag1
# 0                      Level Infinite   3.167     4.1    318000  Role Playing
# 1                         XFLAG, Inc.   4.768     4.0    785000  Role Playing
# 2                       Cygames, Inc.   4.973     4.0     97100    Simulation
# 3                              KONAMI   5.984     4.2     91800        Sports
# 4               COGNOSPHERE PTE. LTD.   7.027     4.4   3810000  Role Playing
# 5   GungHo Online Entertainment, Inc.   7.597     4.9    142000        Puzzle
# 6   GungHo Online Entertainment, Inc.   7.597     4.9    142000        Puzzle
# 7                        Aniplex Inc.   8.272     3.8    169000  Role Playing
# 8                      miHoYo Limited   9.717     4.4   3810000  Role Playing
# 9                       Niantic, Inc.  10.194     3.7  15400000        Action
# 10            Bank of Innovation, Inc  10.283     4.0     44500  Role Playing
# 11                      NetEase Games  10.445     3.9    559000     Adventure
# 12                        SQUARE ENIX  10.856     3.5     68500  Role Playing
# 13                            37GAMES  12.909     4.1   1470000        Puzzle
# 14                            37GAMES  15.389     3.9    242000  Role Playing
# 15    BANDAI NAMCO Entertainment Inc.  15.598     4.2    229000  Role Playing
# 16                 Happy Elements K.K  16.009     4.5     19800         Music
# 17                        SQUARE ENIX  16.818     3.8     75900  Role Playing
# 18                        SQUARE ENIX  16.818     3.8     75900  Role Playing
# 19                    C4 CONNECT K.K.  17.271     4.1     96900  Role Playing
# 20                    C4 CONNECT K.K.  18.032     4.1     96900  Role Playing
# 21                          WFS, Inc.  18.061     4.2     36200  Role Playing
# 22         KOEI TECMO GAMES CO., LTD.  18.250     3.5      1360    Simulation
# 23                   SEGA CORPORATION  19.466     4.4     97300         Music
# 24                     Level Infinite  19.909     4.0    192000  Role Playing
# 25                      NetEase Games  20.000     4.3     16600      Strategy
# 26                        Aiming Inc.  20.250     3.8      3300  Role Playing
# 27    BANDAI NAMCO Entertainment Inc.  21.108     4.3     46900        Action
# 28    BANDAI NAMCO Entertainment Inc.  21.108     4.3     46900        Action
# 29    BANDAI NAMCO Entertainment Inc.  21.108     4.3     46900        Action
# 30                        SQUARE ENIX  22.276     3.8     75900  Role Playing
# 31          Spotlight Network Limited  22.671     4.0     18200  Role Playing
# 32                             KONAMI  22.925     3.6    141000          Card
# 33    BANDAI NAMCO Entertainment Inc.  22.942     4.3    459000  Role Playing
# 34                   LINE Corporation  22.995     3.8   1220000        Puzzle
# 35                        SQUARE ENIX  23.286     3.1     14100  Role Playing
# 36                        SQUARE ENIX  23.397     3.7     50300  Role Playing
# 37                YOTTA GAMES PTE LTD  23.415     4.1   1280000      Strategy
# 38    BANDAI NAMCO Entertainment Inc.  23.576     3.9     82900        Action
# 39              Thatgamecompany, Inc.  24.806     4.3    855000     Adventure
# 40                      GOODROID,Inc.  25.000     4.0      1740        Puzzle
# 41       YOOZOO (SINGAPORE) PTE. LTD.  25.105     4.5     34900  Role Playing
# 42                             KONAMI  25.217     3.7  10700000        Sports
# 43                       Aniplex Inc.  25.328     4.1     64600  Role Playing
# 44                      Cygames, Inc.  25.468     4.1    390000  Role Playing
# 45                   NHN PlayArt 株式会社  25.500     3.9      9380  Productivity
# 46                             KONAMI  25.562     4.4     96500        Sports
# 47                   LINE Corporation  25.565     4.1    453000        Puzzle
# 48                       Yostar, Inc.  25.721     4.6     27000      Strategy
# 49                        SQUARE ENIX  25.848     3.8    137000  Role Playing

# %%
# sorting by the ranking in descending order
games_ranking = games.sort_values('rank',ascending=False).reset_index().drop('index',axis=1)
games_ranking
# Out:
#                                     title                        publisher  \
# 0    Ikémen Sengoku: Romances Across Time                 CYBIRD Co., Ltd.
# 1                             KOF ALLSTAR            Netmarble Corporation
# 2                THE IDOLM@STER POP LINKS  BANDAI NAMCO Entertainment Inc.
# 3         Forsaken World: Gods and Demons                 4399 NET LIMITED
# 4          Hajime no Ippo: Fighting Souls                       Rudel inc.
# ..                                    ...                              ...
# 284         Genshin Impact - Sumeru Debut            COGNOSPHERE PTE. LTD.
# 285       Professional Baseball Spirits A                           KONAMI
# 286               Uma Musume Pretty Derby                    Cygames, Inc.
# 287                        Monster Strike                      XFLAG, Inc.
# 288             GODDESS OF VICTORY: NIKKE                   Level Infinite
#
#      capital    rank        dl  rating   review          tag1  \
# 0     Public  50.000   1000000     3.9    12700    Simulation
# 1     Public  50.000    100000     3.3    15900        Action
# 2     Public  50.000    100000     3.9     5420  Role Playing
# 3    Private  49.333    100000     3.0     4710  Role Playing
# 4    Private  49.000    100000     4.2     6530  Role Playing
# ..       ...     ...       ...     ...      ...           ...
# 284  Private   7.027  50000000     4.4  3810000  Role Playing
# 285   Public   5.984   1000000     4.2    91800        Sports
# 286   Public   4.973   1000000     4.0    97100    Simulation
# 287   Public   4.768  10000000     4.0   785000  Role Playing
# 288   Public   3.167   1000000     4.1   318000  Role Playing
#
#                     tag2                tag3                     tag4  \
# 0                   Life              Dating            Single player
# 1               Fighting       Single player                 Stylized
# 2                      -                   -                        -
# 3                 MMORPG       Single player                 Stylized
# 4        Action-strategy       Single player                 Stylized
# ..                   ...                 ...                      ...
# 284  Action Role-Playing       Single player                 Stylized
# 285             Baseball         Multiplayer  Competitive multiplayer
# 286             Breeding            Stylized                    Anime
# 287  Puzzle Role-playing  Physics-puzzle RPG            Single player
# 288  Action Role-Playing              Casual            Single player
#
#                    tag5       tag6
# 0              Stylized      Anime
# 1                 Anime          -
# 2                     -          -
# 3    Stylized-realistic          -
# 4                 Anime          -
# ..                  ...        ...
# 284               Anime          -
# 285       Single player  Realistic
# 286                   -          -
# 287            Stylized      Anime
# 288            Stylized      Anime
#
# [289 rows x 13 columns]

# %%
# Show worst 50 results 
display(games_ranking[['title','publisher','rank','rating','review','tag1']].nlargest(50,'rank'))
# Out:
#                                            title  \
# 0           Ikémen Sengoku: Romances Across Time
# 1                                    KOF ALLSTAR
# 2                       THE IDOLM@STER POP LINKS
# 3                Forsaken World: Gods and Demons
# 4                 Hajime no Ippo: Fighting Souls
# 5           Akashic Chronicle-Apocalypse Of Dawn
# 6                            Artery Gear: Fusion
# 7                   Boso Retsuden Tansha No Tora
# 8                     Lords Mobile: Kingdom Wars
# 9                                     LINE POP2
# 10                          HELIOS Rising Heroes
# 11                   Ekimemo! -Station Memories!
# 12                                   Royal Match
# 13                 THE KING OF FIGHTERS '98UM OL
# 14                    \nSaint Seiya: Rising Cosm
# 15                              White Cat Tennis
# 16                           Cookie Run: Kingdom
# 17                 Gundam Battle: Gunpla Warfare
# 18                   BlackStar -Theater Starless
# 19                       Dead by Daylight Mobile
# 20                               Mario Kart Tour
# 21                                  Figure Story
# 22                   The Walking Dead: Survivors
# 23                                   City Dunk 2
# 24              Sword Art Online Unleash Blading
# 25                         Age of Three Kingdoms
# 26                              Tenchi no Gotoku
# 27                                     Lineage2M
# 28                               Path to Nowhere
# 29                        Ensemble Stars!! Basic
# 30                             Kirameki Paradise
# 31                         Lineage 2: Revolution
# 32                Ragnarok Origin: MMORPG Online
# 33                    Best Eleven-CHAMPIONS CLUB
# 34            Shin Megami Tensei: Liberation Dx2
# 35                                Daily Interior
# 36                         Monster Hunter Riders
# 37                       BTS Island: In the SEOM
# 38        Fist of the North Star: Legends ReVIVE
# 39                                      Township
# 40  100 Sleeping Princes & the Kingdom of Dreams
# 41           Dissidia Final Fantasy: Opera Omnia
# 42                                    Dragon Egg
# 43                            Net Mahjong Mobile
# 44                              Ragnarok Masters
# 45                               E.T.E Chronicle
# 46              Rise-Hana and Takeshi no Sengoku
# 47                                  Survivor!.io
# 48                 Prince of Tennis: Rising Beat
# 49                                   Epic Seven
#
#                                      publisher    rank  rating   review  \
# 0                             CYBIRD Co., Ltd.  50.000     3.9    12700
# 1                        Netmarble Corporation  50.000     3.3    15900
# 2              BANDAI NAMCO Entertainment Inc.  50.000     3.9     5420
# 3                             4399 NET LIMITED  49.333     3.0     4710
# 4                                   Rudel inc.  49.000     4.2     6530
# 5                                     Moonton   49.000     4.1    11400
# 6                            BILIBILI CO.,LTD.  49.000     3.2     3380
# 7                              Donuts Co. Ltd.  49.000     3.5    49600
# 8                                      IGG.COM  48.667     4.2  8010000
# 9                             LINE Corporation  48.500     4.4   238000
# 10                          Happy Elements K.K  48.000     4.3     3660
# 11                                g1dash, Inc.  47.714     3.4     7500
# 12                           Dream Games, Ltd.  47.625     4.0  1430000
# 13                         FINGERFUN PTE. LTD.  47.500     3.9    20800
# 14                                    Tencent   47.286     3.8    23600
# 15                                COLOPL, Inc.  47.000     3.0    79900
# 16                                  Devsisters  47.000     4.2   986000
# 17             BANDAI NAMCO Entertainment Inc.  46.500     3.7    32100
# 18                             Donuts Co. Ltd.  46.000     4.4     4230
# 19  NETEASE INTERACTIVE ENTERTAINMENT PTE. LTD  46.000     3.8    33700
# 20                          Nintendo Co., Ltd.  46.000     3.7  2080000
# 21                 Nuverse (Hong Kong) Limited  46.000     4.0     7750
# 22              Galaxy Play Technology Limited  46.000     3.9   810000
# 23                                Cookies Inc.  46.000     4.1     4070
# 24             BANDAI NAMCO Entertainment Inc.  46.000     3.7    18800
# 25                              Six Waves Inc.  45.500     4.0     4560
# 26                              Six Waves Inc.  45.250     4.7     5670
# 27                                      NCSOFT  45.250     3.3     4650
# 28                                  AISNOGames  45.200     4.3    80100
# 29                          Happy Elements K.K  45.000     4.3    53400
# 30                        Famous Heart Limited  45.000     4.7      855
# 31                       Netmarble Corporation  44.750     2.9    25800
# 32           GungHo Online Entertainment, Inc.  44.706     2.2     2020
# 33              Gala Sports Technology Limited  44.500     4.2     1460
# 34                            SEGA CORPORATION  44.500     3.8    21700
# 35                                        Ujoy  44.182     4.2    20800
# 36                                      CAPCOM  44.000     3.6      815
# 37                            HYBE IM Co.,Ltd.  44.000     4.5   445000
# 38                                        SEGA  43.829     3.5    18700
# 39                                     Playrix  43.706     4.0  9610000
# 40                                     GCREST   43.667     3.9    23700
# 41                                 SQUARE ENIX  43.667     3.2    18700
# 42                                  Rudel inc.  43.667     4.1    43200
# 43                            SEGA CORPORATION  43.409     3.6    72200
# 44           GungHo Online Entertainment, Inc.  43.400     0.0        0
# 45                           BILIBILI CO.,LTD.  43.333     3.6     3730
# 46                YOOZOO (SINGAPORE) PTE. LTD.  43.283     3.7    15000
# 47                                       HABBY  43.256     4.5   532000
# 48                                  Bushiroad   43.000     4.2     9920
# 49                          Smilegate Megaport  42.833     4.1   453000
#
#             tag1
# 0     Simulation
# 1         Action
# 2   Role Playing
# 3   Role Playing
# 4   Role Playing
# 5   Role Playing
# 6   Role Playing
# 7   Role Playing
# 8       Strategy
# 9         Puzzle
# 10  Role Playing
# 11     Adventure
# 12        Puzzle
# 13        Action
# 14  Role Playing
# 15        Sports
# 16  Role Playing
# 17  Role Playing
# 18         Music
# 19        Action
# 20        Racing
# 21  Role Playing
# 22      Strategy
# 23        Sports
# 24  Role Playing
# 25      Strategy
# 26      Strategy
# 27  Role Playing
# 28  Role Playing
# 29    Simulation
# 30    Simulation
# 31  Role Playing
# 32  Role Playing
# 33        Sports
# 34  Role Playing
# 35    Simulation
# 36  Role Playing
# 37        Puzzle
# 38  Role Playing
# 39    Simulation
# 40  Role Playing
# 41  Role Playing
# 42  Role Playing
# 43         Board
# 44  Role Playing
# 45  Role Playing
# 46    Simulation
# 47  Role Playing
# 48         Music
# 49  Role Playing

# %% [markdown]
# **Relationship between variables**

# %%
games_sub = games[['rank','rating','review','dl']]
corrs = games_sub.corr()

# Set the default matplotlib figure size:
fig, ax = plt.subplots(figsize=(14,8))

# Generate a mask for the upper triangle
mask = np.zeros_like(corrs, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Plot the heatmap with seaborn.
# Assign the matplotlib axis the function returns.
ax = sns.heatmap(corrs, mask=mask)

# Resize the labels.
ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14, rotation=90)
ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14, rotation=0)

plt.title("Correlation of variables", fontsize= 30)

# If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
plt.show()

# %% [markdown]
# # 4. Fit Model:

# %% [markdown]
# [ADDITIONAL] K-Means Clustering is used to profile gaming apps with similar trends in grossing ranks (SimilarWeb) and user rating (Google Play). K-Means Clustering is an unsupervised machine learning technique in which the
# algorithm clusters the data in an iterative manner. It is used to cluster or profile unlabeled data to predict the class of observations without a target vector. The ‘K’ value here denotes the number of clusters. I chose this methodology as it serves better to analyze a large data set which exhibits different attributes depending on differernt labels.

# %% [markdown]
# [ADDITIONAL] In this project, the elbow method was utilized to find the optimal value of number of clusters – ‘K’. The elbow method aims to find that value of ‘K’ such that there is not substantial decrease in the within cluster sum of squares (WCSS) value. The "Error vs K" charts returned the optimal value of ‘K’ selected, which happened to be 4 out of 15 (the total number of gaming app genres).

# %%
from scipy import stats
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# clustering categories into group of similarity using KMeans.
games_cluster = games[['tag1','rank','rating','review','dl']].groupby("tag1").agg(['mean','median'])
games_cluster
# Out:
#                     rank             rating               review            \
#                     mean   median      mean median          mean    median
# tag1
# Action         33.403444  35.8320  3.800000   3.85  4.005316e+06     46900
# Adventure      28.529250  27.9790  3.900000   3.95  3.577100e+05    284170
# Board          35.816500  35.8165  3.700000   3.70  7.395000e+04     73950
# Card           28.124250  28.6710  3.700000   3.75  6.117500e+05    103400
# Casino         36.800000  36.8000  3.350000   3.35  2.343400e+05    234340
# Casual         39.591000  39.5910  3.650000   3.65  1.611045e+07  16110450
# Music          33.206375  32.3435  4.312500   4.30  3.015312e+04     13200
# Productivity   27.916500  27.9165  3.900000   3.90  9.380000e+03      9380
# Puzzle         30.846526  31.6020  4.142105   4.10  2.090591e+06    453000
# Racing         41.666667  41.5000  3.733333   3.70  7.178000e+05     49400
# Role Playing   34.379638  36.3160  3.793289   3.90  1.955882e+05     33900
# Simulation     37.060905  38.5000  3.947619   3.90  5.103564e+05     13900
# Single player  38.179000  38.1790  4.400000   4.40  7.780000e+02       778
# Sports         34.793625  37.7000  3.843750   3.85  2.036661e+06     28000
# Strategy       35.467333  36.1450  4.066667   4.10  3.913129e+06     28900
#
#                          dl
#                        mean     median
# tag1
# Action         2.424722e+07    1000000
# Adventure      5.150000e+06    5250000
# Board          1.000000e+06    1000000
# Card           1.312500e+07    1000000
# Casino         5.050000e+06    5050000
# Casual         2.500500e+08  250050000
# Music          3.687500e+05     100000
# Productivity   1.000000e+05     100000
# Puzzle         2.798158e+07   10000000
# Racing         3.383333e+07    1000000
# Role Playing   3.298389e+06     500000
# Simulation     5.645714e+06     500000
# Single player  1.000000e+04      10000
# Sports         2.005312e+07    1000000
# Strategy       3.692333e+07     750000

# %% [markdown]
# **1. Clustering by download cases and Google Play rating**

# %%
games_cluster = pd.concat([games_cluster.xs(('dl','mean') , axis = 1), games_cluster.xs(('rating','median') , axis = 1)], axis = 1)
games_cluster.head(15)
# Out:
#                          dl rating
#                        mean median
# tag1
# Action         2.424722e+07   3.85
# Adventure      5.150000e+06   3.95
# Board          1.000000e+06   3.70
# Card           1.312500e+07   3.75
# Casino         5.050000e+06   3.35
# Casual         2.500500e+08   3.65
# Music          3.687500e+05   4.30
# Productivity   1.000000e+05   3.90
# Puzzle         2.798158e+07   4.10
# Racing         3.383333e+07   3.70
# Role Playing   3.298389e+06   3.90
# Simulation     5.645714e+06   3.90
# Single player  1.000000e+04   4.40
# Sports         2.005312e+07   3.85
# Strategy       3.692333e+07   4.10

# %%
games_cluster = games_cluster.droplevel(1, axis = 1)

# %%
scaler = StandardScaler().fit(games_cluster)
games_cluster_std = scaler.transform(games_cluster)

# %%
error = []
for i in range(1,15): # we only have 15 categories, this is prabably too much.
    km = KMeans(n_clusters = i, init = 'k-means++', random_state = 101).fit(games_cluster_std)
    error.append(km.inertia_)

# %%
plt.plot(range(1,15), error, marker = 'D', markerfacecolor = 'red', color = 'blue', markeredgecolor = 'red')
plt.title("Error VS K")
plt.xlabel('K')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %%
# Fit KMeans with optimal K
km = KMeans(n_clusters = 4, init = 'k-means++', random_state = 101).fit(games_cluster_std)
pred = km.labels_
centroids = km.cluster_centers_

# %% [markdown]
# **Result**

# %%
# result
result = games_cluster.copy()
result.reset_index(inplace = True)
result['cluster'] = pred
# result = pd.DataFrame(np.column_stack((df_cluster.index, pred)), columns = ['category','cluster'])
result.head()
# Out:
#         tag1            dl  rating  cluster
# 0     Action  2.424722e+07    3.85        0
# 1  Adventure  5.150000e+06    3.95        0
# 2      Board  1.000000e+06    3.70        0
# 3       Card  1.312500e+07    3.75        0
# 4     Casino  5.050000e+06    3.35        3

# %%
fig_r, ax_r = plt.subplots(figsize = (15,10))

sns.scatterplot(x = 'dl', y = 'rating', hue = 'cluster', palette = 'gist_rainbow', 
                data = result, s = 500, ax = ax_r)


plt.legend(bbox_to_anchor = (1,1), title = 'cluster')

for i in range(result.shape[0]):
    
    if result.iloc[i,0] == 'Adventure':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Productivity':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='top',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Simulation':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Role Playing':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    else:
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='top',size='medium', color='black', weight='semibold',rotation=45)
        
    
plt.title("Cluster by genre",fontweight='bold',fontsize=20)
plt.show()

# %% [markdown]
# **Cluster Result**
#
# (a) Cluster 0 red
# (Adventure, Role-Playing, Simulation, Productivity, Sports, Actinos, Board, Card, Racing)
# Medium-high rating and small-medium average D/L cases.
#
# (b) Cluster 1 green
# (Casual)
# Medium-low rating and large average number of D/L cases.
#
# (c) Cluster 2 blue
# (Single Player, Music, Puzzle, Strategy)
# High rating and small average number of D/L cases.
#
# (d) Cluster 3 Pink
# (Casino)
# Low rating and small average number of D/L cases.

# %% [markdown]
# **2. Clustering by review counts and Google Play rating**

# %%
# clustering categories into group of similarity using KMeans.
games_cluster_2 = games[['tag1','review','dl','rank','rating']].groupby("tag1").agg(['mean','median'])
games_cluster_2
# Out:
#                      review                      dl                  rank  \
#                        mean    median          mean     median       mean
# tag1
# Action         4.005316e+06     46900  2.424722e+07    1000000  33.403444
# Adventure      3.577100e+05    284170  5.150000e+06    5250000  28.529250
# Board          7.395000e+04     73950  1.000000e+06    1000000  35.816500
# Card           6.117500e+05    103400  1.312500e+07    1000000  28.124250
# Casino         2.343400e+05    234340  5.050000e+06    5050000  36.800000
# Casual         1.611045e+07  16110450  2.500500e+08  250050000  39.591000
# Music          3.015312e+04     13200  3.687500e+05     100000  33.206375
# Productivity   9.380000e+03      9380  1.000000e+05     100000  27.916500
# Puzzle         2.090591e+06    453000  2.798158e+07   10000000  30.846526
# Racing         7.178000e+05     49400  3.383333e+07    1000000  41.666667
# Role Playing   1.955882e+05     33900  3.298389e+06     500000  34.379638
# Simulation     5.103564e+05     13900  5.645714e+06     500000  37.060905
# Single player  7.780000e+02       778  1.000000e+04      10000  38.179000
# Sports         2.036661e+06     28000  2.005312e+07    1000000  34.793625
# Strategy       3.913129e+06     28900  3.692333e+07     750000  35.467333
#
#                           rating
#                 median      mean median
# tag1
# Action         35.8320  3.800000   3.85
# Adventure      27.9790  3.900000   3.95
# Board          35.8165  3.700000   3.70
# Card           28.6710  3.700000   3.75
# Casino         36.8000  3.350000   3.35
# Casual         39.5910  3.650000   3.65
# Music          32.3435  4.312500   4.30
# Productivity   27.9165  3.900000   3.90
# Puzzle         31.6020  4.142105   4.10
# Racing         41.5000  3.733333   3.70
# Role Playing   36.3160  3.793289   3.90
# Simulation     38.5000  3.947619   3.90
# Single player  38.1790  4.400000   4.40
# Sports         37.7000  3.843750   3.85
# Strategy       36.1450  4.066667   4.10

# %%
games_cluster_2 = pd.concat([games_cluster_2.xs(('review','mean'), axis = 1), games_cluster_2.xs(('rating','median'), axis = 1)], axis = 1)
games_cluster_2.head(15)
# Out:
#                      review rating
#                        mean median
# tag1
# Action         4.005316e+06   3.85
# Adventure      3.577100e+05   3.95
# Board          7.395000e+04   3.70
# Card           6.117500e+05   3.75
# Casino         2.343400e+05   3.35
# Casual         1.611045e+07   3.65
# Music          3.015312e+04   4.30
# Productivity   9.380000e+03   3.90
# Puzzle         2.090591e+06   4.10
# Racing         7.178000e+05   3.70
# Role Playing   1.955882e+05   3.90
# Simulation     5.103564e+05   3.90
# Single player  7.780000e+02   4.40
# Sports         2.036661e+06   3.85
# Strategy       3.913129e+06   4.10

# %%
games_cluster_2 = games_cluster_2.droplevel(1, axis = 1)

# %%
scaler = StandardScaler().fit(games_cluster_2)
games_cluster_2_std = scaler.transform(games_cluster_2)

# %%
error = []
for i in range(1,15): # we only have 15 categories, this is prabably too much.
    km = KMeans(n_clusters = i, init = 'k-means++', random_state = 101).fit(games_cluster_2_std)
    error.append(km.inertia_)

# %%
plt.plot(range(1,15), error, marker = 'D', markerfacecolor = 'red', color = 'blue', markeredgecolor = 'red')
plt.title("Error VS K")
plt.xlabel('K')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %%
# Fit KMeans with optimal K
km = KMeans(n_clusters = 4, init = 'k-means++', random_state = 101).fit(games_cluster_2_std)
pred = km.labels_
centroids = km.cluster_centers_

# %% [markdown]
# **Result**

# %%
# result
result = games_cluster_2
result.reset_index(inplace = True)
result['cluster'] = pred
# result = pd.DataFrame(np.column_stack((df_cluster.index, pred)), columns = ['category','cluster'])
result.head()
# Out:
#         tag1        review  rating  cluster
# 0     Action  4.005316e+06    3.85        0
# 1  Adventure  3.577100e+05    3.95        0
# 2      Board  7.395000e+04    3.70        0
# 3       Card  6.117500e+05    3.75        0
# 4     Casino  2.343400e+05    3.35        3

# %%
fig_r, ax_r = plt.subplots(figsize = (15,10))

sns.scatterplot(x = 'review', y = 'rating', hue = 'cluster', palette = 'gist_rainbow', 
                data = result, s = 500, ax = ax_r)


plt.legend(bbox_to_anchor = (1,1), title = 'cluster')

for i in range(result.shape[0]):
    
    if result.iloc[i,0] == 'Adventure':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Productivity':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='top',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Simulation':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Role Playing':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    else:
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='top',size='medium', color='black', weight='semibold',rotation=45)
        
    
plt.title("Cluster by genre",fontweight='bold',fontsize=20)
plt.show()

# %% [markdown]
# **Cluster Result**
#
# (a) Cluster 0 red
# (Adventure, Role-Playing, Simulation, Productivity, Sports, Actinos, Board, Card, Racing)
# Medium-high rating and small-medium average review counts.
#
# (b) Cluster 1 green
# (Casual)
# Medium-low rating and large average number of review counts.
#
# (c) Cluster 2 blue
# (Single Player, Music, Puzzle, Strategy)
# High rating and small average number of review counts.
#
# (d) Cluster 3 Pink
# (Casino)
# Low rating and small average number of review counts.

# %% [markdown]
# **3. Clustering by Google Play download cases and SimilarWeb ranking**

# %%
# clustering categories into group of similarity using KMeans.
games_cluster_3 = games[['tag1','rank','rating','review','dl']].groupby("tag1").agg(['mean','median'])
games_cluster_3
# Out:
#                     rank             rating               review            \
#                     mean   median      mean median          mean    median
# tag1
# Action         33.403444  35.8320  3.800000   3.85  4.005316e+06     46900
# Adventure      28.529250  27.9790  3.900000   3.95  3.577100e+05    284170
# Board          35.816500  35.8165  3.700000   3.70  7.395000e+04     73950
# Card           28.124250  28.6710  3.700000   3.75  6.117500e+05    103400
# Casino         36.800000  36.8000  3.350000   3.35  2.343400e+05    234340
# Casual         39.591000  39.5910  3.650000   3.65  1.611045e+07  16110450
# Music          33.206375  32.3435  4.312500   4.30  3.015312e+04     13200
# Productivity   27.916500  27.9165  3.900000   3.90  9.380000e+03      9380
# Puzzle         30.846526  31.6020  4.142105   4.10  2.090591e+06    453000
# Racing         41.666667  41.5000  3.733333   3.70  7.178000e+05     49400
# Role Playing   34.379638  36.3160  3.793289   3.90  1.955882e+05     33900
# Simulation     37.060905  38.5000  3.947619   3.90  5.103564e+05     13900
# Single player  38.179000  38.1790  4.400000   4.40  7.780000e+02       778
# Sports         34.793625  37.7000  3.843750   3.85  2.036661e+06     28000
# Strategy       35.467333  36.1450  4.066667   4.10  3.913129e+06     28900
#
#                          dl
#                        mean     median
# tag1
# Action         2.424722e+07    1000000
# Adventure      5.150000e+06    5250000
# Board          1.000000e+06    1000000
# Card           1.312500e+07    1000000
# Casino         5.050000e+06    5050000
# Casual         2.500500e+08  250050000
# Music          3.687500e+05     100000
# Productivity   1.000000e+05     100000
# Puzzle         2.798158e+07   10000000
# Racing         3.383333e+07    1000000
# Role Playing   3.298389e+06     500000
# Simulation     5.645714e+06     500000
# Single player  1.000000e+04      10000
# Sports         2.005312e+07    1000000
# Strategy       3.692333e+07     750000

# %%
games_cluster_3 = pd.concat([games_cluster_3.xs(('dl','mean'), axis = 1), games_cluster_3.xs(('rank','median'), axis = 1)], axis = 1)
games_cluster_3.head(15)
# Out:
#                          dl     rank
#                        mean   median
# tag1
# Action         2.424722e+07  35.8320
# Adventure      5.150000e+06  27.9790
# Board          1.000000e+06  35.8165
# Card           1.312500e+07  28.6710
# Casino         5.050000e+06  36.8000
# Casual         2.500500e+08  39.5910
# Music          3.687500e+05  32.3435
# Productivity   1.000000e+05  27.9165
# Puzzle         2.798158e+07  31.6020
# Racing         3.383333e+07  41.5000
# Role Playing   3.298389e+06  36.3160
# Simulation     5.645714e+06  38.5000
# Single player  1.000000e+04  38.1790
# Sports         2.005312e+07  37.7000
# Strategy       3.692333e+07  36.1450

# %%
games_cluster_3 = games_cluster_3.droplevel(1, axis = 1)

# %%
scaler = StandardScaler().fit(games_cluster_3)
games_cluster_3_std = scaler.transform(games_cluster_3)

# %%
error = []
for i in range(1,15): # we only have 15 categories, this is prabably too much.
    km = KMeans(n_clusters = i, init = 'k-means++', random_state = 101).fit(games_cluster_3_std)
    error.append(km.inertia_)

# %%
plt.plot(range(1,15), error, marker = 'D', markerfacecolor = 'red', color = 'blue', markeredgecolor = 'red')
plt.title("Error VS K")
plt.xlabel('K')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %%
# Fit KMeans with optimal K
km = KMeans(n_clusters = 4, init = 'k-means++', random_state = 101).fit(games_cluster_3_std)
pred = km.labels_
centroids = km.cluster_centers_

# %% [markdown]
# **Result**

# %%
# result
result = games_cluster_3
result.reset_index(inplace = True)
result['cluster'] = pred
# result = pd.DataFrame(np.column_stack((df_cluster.index, pred)), columns = ['category','cluster'])
result.head()
# Out:
#         tag1            dl     rank  cluster
# 0     Action  2.424722e+07  35.8320        0
# 1  Adventure  5.150000e+06  27.9790        1
# 2      Board  1.000000e+06  35.8165        0
# 3       Card  1.312500e+07  28.6710        1
# 4     Casino  5.050000e+06  36.8000        0

# %%
fig_r, ax_r = plt.subplots(figsize = (15,10))

sns.scatterplot(x = 'dl', y = 'rank', hue = 'cluster', palette = 'gist_rainbow', 
                data = result, s = 500, ax = ax_r).invert_yaxis()


plt.legend(bbox_to_anchor = (1,1), title = 'cluster')

for i in range(result.shape[0]):
    
    if result.iloc[i,0] == 'Adventure':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Productivity':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Simulation':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Role Playing':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    else:
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
        
    
plt.title("Cluster by genre",fontweight='bold',fontsize=20)
plt.show()

# %% [markdown]
# **Cluster Result**
#
# (a) Cluster 0 red
# (Strategy, Role-Playing, Simulation, Single-Player, Sports, Action, Board, Casino)
# Medium-high ranking and small average D/L cases.
#
# (b) Cluster 1 green
# (Productivity, Adventure, Card, Music, Puzzle)
# High ranking and small average D/L cases.
#
# (c) Cluster 2 blue
# (Casual)
# Medium-low ranking and large average D/L cases.
#
# (d) Cluster 3 Pink
# (Racing)
# Low ranking and small number of D/L cases.

# %% [markdown]
# **4. Clustering by Google Play review counts and SimilarWeb ranking**

# %%
# clustering categories into group of similarity using KMeans.
games_cluster_4 = games[['tag1','rank','rating','review','dl']].groupby("tag1").agg(['mean','median'])
games_cluster_4
# Out:
#                     rank             rating               review            \
#                     mean   median      mean median          mean    median
# tag1
# Action         33.403444  35.8320  3.800000   3.85  4.005316e+06     46900
# Adventure      28.529250  27.9790  3.900000   3.95  3.577100e+05    284170
# Board          35.816500  35.8165  3.700000   3.70  7.395000e+04     73950
# Card           28.124250  28.6710  3.700000   3.75  6.117500e+05    103400
# Casino         36.800000  36.8000  3.350000   3.35  2.343400e+05    234340
# Casual         39.591000  39.5910  3.650000   3.65  1.611045e+07  16110450
# Music          33.206375  32.3435  4.312500   4.30  3.015312e+04     13200
# Productivity   27.916500  27.9165  3.900000   3.90  9.380000e+03      9380
# Puzzle         30.846526  31.6020  4.142105   4.10  2.090591e+06    453000
# Racing         41.666667  41.5000  3.733333   3.70  7.178000e+05     49400
# Role Playing   34.379638  36.3160  3.793289   3.90  1.955882e+05     33900
# Simulation     37.060905  38.5000  3.947619   3.90  5.103564e+05     13900
# Single player  38.179000  38.1790  4.400000   4.40  7.780000e+02       778
# Sports         34.793625  37.7000  3.843750   3.85  2.036661e+06     28000
# Strategy       35.467333  36.1450  4.066667   4.10  3.913129e+06     28900
#
#                          dl
#                        mean     median
# tag1
# Action         2.424722e+07    1000000
# Adventure      5.150000e+06    5250000
# Board          1.000000e+06    1000000
# Card           1.312500e+07    1000000
# Casino         5.050000e+06    5050000
# Casual         2.500500e+08  250050000
# Music          3.687500e+05     100000
# Productivity   1.000000e+05     100000
# Puzzle         2.798158e+07   10000000
# Racing         3.383333e+07    1000000
# Role Playing   3.298389e+06     500000
# Simulation     5.645714e+06     500000
# Single player  1.000000e+04      10000
# Sports         2.005312e+07    1000000
# Strategy       3.692333e+07     750000

# %%
games_cluster_4 = pd.concat([games_cluster_4.xs(('review','mean'), axis = 1), games_cluster_4.xs(('rank','median'), axis = 1)], axis = 1)
games_cluster_4.head(15)
# Out:
#                      review     rank
#                        mean   median
# tag1
# Action         4.005316e+06  35.8320
# Adventure      3.577100e+05  27.9790
# Board          7.395000e+04  35.8165
# Card           6.117500e+05  28.6710
# Casino         2.343400e+05  36.8000
# Casual         1.611045e+07  39.5910
# Music          3.015312e+04  32.3435
# Productivity   9.380000e+03  27.9165
# Puzzle         2.090591e+06  31.6020
# Racing         7.178000e+05  41.5000
# Role Playing   1.955882e+05  36.3160
# Simulation     5.103564e+05  38.5000
# Single player  7.780000e+02  38.1790
# Sports         2.036661e+06  37.7000
# Strategy       3.913129e+06  36.1450

# %%
games_cluster_4 = games_cluster_4.droplevel(1, axis = 1)

# %%
scaler = StandardScaler().fit(games_cluster_4)
games_cluster_4_std = scaler.transform(games_cluster_4)

# %%
error = []
for i in range(1,15): # we only have 15 categories, this is prabably too much.
    km = KMeans(n_clusters = i, init = 'k-means++', random_state = 101).fit(games_cluster_4_std)
    error.append(km.inertia_)

# %%
plt.plot(range(1,15), error, marker = 'D', markerfacecolor = 'red', color = 'blue', markeredgecolor = 'red')
plt.title("Error VS K")
plt.xlabel('K')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %%
# Fit KMeans with optimal K
km = KMeans(n_clusters = 4, init = 'k-means++', random_state = 101).fit(games_cluster_4_std)
pred = km.labels_
centroids = km.cluster_centers_

# %% [markdown]
# **Result**

# %%
# result
result = games_cluster_4
result.reset_index(inplace = True)
result['cluster'] = pred
# result = pd.DataFrame(np.column_stack((df_cluster.index, pred)), columns = ['category','cluster'])
result.head()
# Out:
#         tag1        review     rank  cluster
# 0     Action  4.005316e+06  35.8320        3
# 1  Adventure  3.577100e+05  27.9790        2
# 2      Board  7.395000e+04  35.8165        0
# 3       Card  6.117500e+05  28.6710        2
# 4     Casino  2.343400e+05  36.8000        0

# %%
fig_r, ax_r = plt.subplots(figsize = (15,10))

sns.scatterplot(x = 'review', y = 'rank', hue = 'cluster', palette = 'gist_rainbow', 
                data = result, s = 500, ax = ax_r).invert_yaxis()


plt.legend(bbox_to_anchor = (1,1), title = 'cluster')

for i in range(result.shape[0]):
    
    if result.iloc[i,0] == 'Adventure':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Productivity':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Simulation':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    if result.iloc[i,0] == 'Role Playing':
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
    else:
        plt.text(result.iloc[i,1], result.iloc[i,2], result.iloc[i,0][0:],horizontalalignment='left',verticalalignment='bottom',size='medium', color='black', weight='semibold',rotation=45)
        
    
plt.title("Cluster by genre",fontweight='bold',fontsize=20)
plt.show()

# %% [markdown]
# **Cluster Result**
#
# (a) Cluster 0 red
# (Board, Role-Playing, Simulation, Single-Player, Sports, Racing, Casino):
# Medium-low ranking and small average review counts.
#
# (b) Cluster 1 green
# (Casual):
# Low ranking and large average review counts.
#
# (c) Cluster 2 blue
# (Productivity, Adventure, Card, Music, Puzzle):
# High ranking and small average review counts.
#
# (d) Cluster 3 Pink
# (Action, Strategy):
# Medium-high ranking medium-small number of review counts.

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# I picked this dataset of top-50 grossing ranking mobile games (according to SimilarWeb) and analyzed them by 15 unique game categories as identified by Google Play. In short, I used KMeans to cluter each genre category into the x-y scatter plot (D/L cases or review counts as x-axis; Google Play rating or SimilarWeb rank as y-axis), which de@icts the casual positive relationship between the game's grossing and casusalness.
#
# I found that:
# 1. Within the mobile game titles under this data set, RPG, Strategy and Simulation are the most common genres spanning across high-rated games and low-rated segments. On the other hand, Music, Card and Puzzle belong to the minority genre groups while Casino,and Racing are least represented in this dataset.
# 2. When we look at the distriution of SimilarWeb rating, the data set is negatively skewed with the median positioned at 4 out of 5.
# 3. Music, Puzzle and Strategy single-player games are those which score the hightest average rating according to Google Play. This exemplfies that the core mobile gamers cluster into titles of these genres. On the other hands, Action and Sports games tend to score lower rating on Google Play. Both groups posted smaller volume of review counts and download cases compared with all the Casual games.
# 4. Based on the correlation efficient matrix, the higher ranking on SimilarWeb, the higher rating on Google Play. On Google Play, the review counts and the download cases are positively correlated.
# 5. On average, the Strategy genre is rated higher than Card genre on Google Play while Card game geenrates higher grossing than the Strategy genre does according to SimilarWeb.
# 6. Google Play gives lowest rating to Casino games while it generates higher grossing than Racing games do according to Simialr Web.
# 7. Casual games are relatively less popular and less profitablle than most of other game genres based on Similar Web and Google Play although boasts the largest number of review counts and the download cases.
